# %% [markdown]
# <a href="https://colab.research.google.com/github/Alam710/facial-emotion-recognition/blob/master/IMED_ExperimentDWCS48_100_epochs_96_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Data Preparation for Classification (Original Image)
import os
from pathlib import Path

data_path = Path('/content/drive/MyDrive/IMED/cropped_data')
label_names = sorted([subfolder.name for subfolder in data_path.glob('*')])
num_classes = len(label_names)

class_counts = [0] * num_classes  # Initialize class counts

# Iterate over each label folder
for i, label_name in enumerate(label_names):
    label_path = data_path / label_name

    # Recursive function to count images in subfolders
    def count_images(folder):
        num_images = 0
        for item in folder.iterdir():
            if item.is_file() and item.suffix.lower() == '.jpg':
                num_images += 1
            elif item.is_dir():
                num_images += count_images(item)
        return num_images

    # Count the number of images within the label folder
    class_counts[i] = count_images(label_path)

# Print the number of images and classes
print('Number of classes:', num_classes)

# Print the number of images for each class
for i, label_name in enumerate(label_names):
    print(f'Class: {label_name}, Number of images: {class_counts[i]}')
# Out:
# Number of classes: 7
# Class: 13_angry, Number of images: 1591
# Class: 14_disgust, Number of images: 1413
# Class: 15_fear, Number of images: 1550
# Class: 16_happy, Number of images: 1322
# Class: 17_sad, Number of images: 1793
# Class: 18_surprise, Number of images: 1051
# Class: 19_neutral, Number of images: 480

# %%
import os
import cv2
import numpy as np
from pathlib import Path
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess_input

data_path = Path('/content/drive/MyDrive/IMED/cropped_data')
label_names = sorted([subfolder.name for subfolder in data_path.glob('*')])
num_classes = len(label_names)
target_image_size = (48, 48)

# Create empty lists for images and labels
images = []
labels = []

# Recursive function to load images from subfolders
def load_images_from_folder(folder):
    for item in folder.iterdir():
        if item.is_dir():
            load_images_from_folder(item)
        elif item.is_file() and item.suffix.lower() == '.jpg':
            # Load the image in color
            image = cv2.imread(str(item))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Resize the image to the target size (224x224)
            image = cv2.resize(image, target_image_size)

            # Preprocess the image
            image = efficientnet_preprocess_input(image)

            # Append the image and label to the lists
            images.append(image)
            labels.append(label_names.index(folder.name))

# Iterate over each label folder
for label_name in label_names:
    label_path = data_path / label_name
    load_images_from_folder(label_path)

# Convert the lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Create an ImageDataGenerator with augmentation settings
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Fit the ImageDataGenerator on your training data
datagen.fit(X_train)

# Define the number of augmented images you want per original image
augmented_images_per_sample = 3

# Create empty lists to store augmented images and labels
augmented_images = []
augmented_labels = []

# Loop through each original image and generate augmented images
for i in range(len(X_train)):
    original_image = X_train[i]
    label = y_train[i]

    # Expand the dimensions of the image to match the expected shape for the generator
    expanded_image = np.expand_dims(original_image, axis=0)

    # Generate augmented images using the generator
    augmented_images_batch = datagen.flow(expanded_image, batch_size=augmented_images_per_sample).next()

    # Append augmented images and labels to the lists
    augmented_images.extend(augmented_images_batch)
    augmented_labels.extend([label] * augmented_images_per_sample)

# Convert lists to numpy arrays
augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

# Concatenate original and augmented data
X_train_augmented = np.concatenate((X_train, augmented_images), axis=0)
y_train_augmented = np.concatenate((y_train, augmented_labels), axis=0)

# %%
# Create checkpoint callback
checkpoint_path = "data_model_checkpoint"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                         save_weights_only=True,
                                                         monitor="val_accuracy",
                                                         save_best_only=True,
                                                         )

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, BatchNormalization, Activation, MaxPooling2D, Add, SeparableConv2D

def conv_block(inputs, filters, kernel_size, strides, padding='same'):
    x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu6')(x)
    return x

def residual_module(inputs, filters, num_blocks, strides):
    x = conv_block(inputs, filters, kernel_size=(1, 1), strides=strides)

    for _ in range(num_blocks):
        y = conv_block(x, filters, kernel_size=(3, 3), strides=(1, 1))
        y = conv_block(y, filters, kernel_size=(3, 3), strides=(1, 1))
        x = Add()([x, y])

    return x

def inverted_residual_structure(inputs, filters, num_blocks):
    x = conv_block(inputs, filters, kernel_size=(1, 1), strides=(1, 1))

    for _ in range(num_blocks):
        y = conv_block(x, filters, kernel_size=(3, 3), strides=(1, 1))
        y = conv_block(y, filters, kernel_size=(3, 3), strides=(1, 1))
        x = Add()([x, y])

    return x

input_shape = (target_image_size[0], target_image_size[1], 3)
num_classes = 7

inputs = tf.keras.Input(shape=input_shape)
x = conv_block(inputs, filters=32, kernel_size=(5, 5), strides=(1, 1))
x = MaxPooling2D(2, 2)(x)
x = conv_block(x, filters=64, kernel_size=(5, 5), strides=(1, 1))
x = MaxPooling2D(2, 2)(x)
x = residual_module(x, filters=128, num_blocks=2, strides=(2, 2))
x = inverted_residual_structure(x, filters=256, num_blocks=4)
x = residual_module(x, filters=256, num_blocks=2, strides=(2, 2))
x = residual_module(x, filters=364, num_blocks=1, strides=(1, 1))
x = residual_module(x, filters=364, num_blocks=2, strides=(2, 2))
x = inverted_residual_structure(x, filters=512, num_blocks=1)
x = SeparableConv2D(filters=728, kernel_size=(1, 1), strides=(1, 1), padding='same')(x)
x = GlobalAveragePooling2D()(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 32)   2432        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 48, 48, 32)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 32)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   51264       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 6, 6, 128)    8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 6, 6, 128)   512         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 6, 6, 128)    147584      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 6, 6, 128)   512         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 6, 6, 128)    147584      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 6, 6, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_4[0][0]']
#
#  add (Add)                      (None, 6, 6, 128)    0           ['activation_2[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 6, 6, 128)    147584      ['add[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 6, 6, 128)   512         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 6, 6, 128)    147584      ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 6, 6, 128)   512         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (None, 6, 6, 128)    0           ['add[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 6, 6, 256)    33024       ['add_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 256)    590080      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 6, 256)    590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 6, 6, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_2 (Add)                    (None, 6, 6, 256)    0           ['activation_7[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 6, 6, 256)    590080      ['add_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (None, 6, 6, 256)    0           ['add_2[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 6, 6, 256)    590080      ['add_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_13[0][0]']
#
#  add_4 (Add)                    (None, 6, 6, 256)    0           ['add_3[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 6, 6, 256)    590080      ['add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_15[0][0]']
#
#  add_5 (Add)                    (None, 6, 6, 256)    0           ['add_4[0][0]',
#                                                                   'activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 3, 3, 256)    65792       ['add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_18[0][0]']
#
#  add_6 (Add)                    (None, 3, 3, 256)    0           ['activation_16[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 3, 3, 256)    590080      ['add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_20[0][0]']
#
#  add_7 (Add)                    (None, 3, 3, 256)    0           ['add_6[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 364)    93548       ['add_7[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 3, 3, 364)    1192828     ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 3, 3, 364)    1192828     ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_23[0][0]']
#
#  add_8 (Add)                    (None, 3, 3, 364)    0           ['activation_21[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 2, 2, 364)    132860      ['add_8[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_26[0][0]']
#
#  add_9 (Add)                    (None, 2, 2, 364)    0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 2, 364)    1192828     ['add_9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_28[0][0]']
#
#  add_10 (Add)                   (None, 2, 2, 364)    0           ['add_9[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 2, 2, 512)    186880      ['add_10[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_31[0][0]']
#
#  add_11 (Add)                   (None, 2, 2, 512)    0           ['activation_29[0][0]',
#                                                                   'activation_31[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 2, 2, 728)   373976      ['add_11[0][0]']
#  v2D)
#
#  global_average_pooling2d (Glob  (None, 728)         0           ['separable_conv2d[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            5103        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,536,151
# Trainable params: 20,518,615
# Non-trainable params: 17,536
# __________________________________________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') >= 0.98):
      print("\nAkurasi telah mencapai > 0.98%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
#from tensorflow.keras.callbacks import EarlyStopping

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# Define early stopping callback
# early_stopping = EarlyStopping(monitor='val_accuracy', patience=0.01, mode='max', verbose=1)

# Train the model with early stopping
history_model = model.fit(X_train, y_train, epochs=100,
                          batch_size=32,
                          validation_data=(X_test, y_test),
                          callbacks=[callbacks])
# Out:
# Epoch 1/100
# 230/230 [==============================] - 39s 26ms/step - loss: 1.4725 - accuracy: 0.4058 - val_loss: 10.4675 - val_accuracy: 0.1179
# Epoch 2/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.9357 - accuracy: 0.6565 - val_loss: 5.5628 - val_accuracy: 0.3196
# Epoch 3/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.7015 - accuracy: 0.7489 - val_loss: 3.0883 - val_accuracy: 0.5342
# Epoch 4/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.5713 - accuracy: 0.8034 - val_loss: 1.4495 - val_accuracy: 0.5793
# Epoch 5/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.4599 - accuracy: 0.8459 - val_loss: 1.2657 - val_accuracy: 0.5614
# Epoch 6/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.3628 - accuracy: 0.8806 - val_loss: 0.5629 - val_accuracy: 0.8071
# Epoch 7/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.3326 - accuracy: 0.8897 - val_loss: 0.5057 - val_accuracy: 0.8435
# Epoch 8/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.2623 - accuracy: 0.9109 - val_loss: 0.4090 - val_accuracy: 0.8690
# Epoch 9/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.2371 - accuracy: 0.9231 - val_loss: 0.5350 - val_accuracy: 0.8359
# Epoch 10/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.2284 - accuracy: 0.9247 - val_loss: 0.4920 - val_accuracy: 0.8478
# Epoch 11/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.1985 - accuracy: 0.9355 - val_loss: 0.5018 - val_accuracy: 0.8576
# Epoch 12/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1678 - accuracy: 0.9433 - val_loss: 0.5466 - val_accuracy: 0.8489
# Epoch 13/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.1407 - accuracy: 0.9545 - val_loss: 0.3078 - val_accuracy: 0.9076
# Epoch 14/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.1456 - accuracy: 0.9533 - val_loss: 0.2826 - val_accuracy: 0.9082
# Epoch 15/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1374 - accuracy: 0.9571 - val_loss: 0.2979 - val_accuracy: 0.9087
# Epoch 16/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.1218 - accuracy: 0.9617 - val_loss: 0.5650 - val_accuracy: 0.8500
# Epoch 17/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.1157 - accuracy: 0.9644 - val_loss: 0.3049 - val_accuracy: 0.9016
# Epoch 18/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.1186 - accuracy: 0.9639 - val_loss: 0.2481 - val_accuracy: 0.9239
# Epoch 19/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0785 - accuracy: 0.9738 - val_loss: 0.4394 - val_accuracy: 0.8848
# Epoch 20/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.1048 - accuracy: 0.9659 - val_loss: 0.3844 - val_accuracy: 0.9005
# Epoch 21/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0956 - accuracy: 0.9696 - val_loss: 0.6561 - val_accuracy: 0.8473
# Epoch 22/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0989 - accuracy: 0.9705 - val_loss: 0.4834 - val_accuracy: 0.8734
# Epoch 23/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0802 - accuracy: 0.9754 - val_loss: 0.3674 - val_accuracy: 0.9022
# Epoch 24/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0709 - accuracy: 0.9781 - val_loss: 0.4801 - val_accuracy: 0.8734
# Epoch 25/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0725 - accuracy: 0.9776 - val_loss: 0.3669 - val_accuracy: 0.8929
# Epoch 26/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0841 - accuracy: 0.9736 - val_loss: 0.2338 - val_accuracy: 0.9408
# Epoch 27/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0752 - accuracy: 0.9780 - val_loss: 0.2591 - val_accuracy: 0.9174
# Epoch 28/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0771 - accuracy: 0.9766 - val_loss: 0.2947 - val_accuracy: 0.9326
# Epoch 29/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0688 - accuracy: 0.9776 - val_loss: 0.8074 - val_accuracy: 0.8261
# Epoch 30/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0672 - accuracy: 0.9781 - val_loss: 0.2911 - val_accuracy: 0.9266
# Epoch 31/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0569 - accuracy: 0.9833 - val_loss: 0.2811 - val_accuracy: 0.9288
# Epoch 32/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0519 - accuracy: 0.9846 - val_loss: 0.4789 - val_accuracy: 0.8842
# Epoch 33/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0377 - accuracy: 0.9890 - val_loss: 0.2666 - val_accuracy: 0.9364
# Epoch 34/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0525 - accuracy: 0.9864 - val_loss: 0.2790 - val_accuracy: 0.9348
# Epoch 35/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0337 - accuracy: 0.9902 - val_loss: 0.3309 - val_accuracy: 0.9125
# Epoch 36/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0699 - accuracy: 0.9812 - val_loss: 0.2725 - val_accuracy: 0.9207
# Epoch 37/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0378 - accuracy: 0.9890 - val_loss: 0.3005 - val_accuracy: 0.9136
# Epoch 38/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0612 - accuracy: 0.9840 - val_loss: 0.2446 - val_accuracy: 0.9321
# Epoch 39/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0923 - accuracy: 0.9755 - val_loss: 0.2878 - val_accuracy: 0.9141
# Epoch 40/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0410 - accuracy: 0.9876 - val_loss: 0.3497 - val_accuracy: 0.9168
# Epoch 41/100
# 230/230 [==============================] - 5s 24ms/step - loss: 0.0440 - accuracy: 0.9887 - val_loss: 0.1842 - val_accuracy: 0.9457
# Epoch 42/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0311 - accuracy: 0.9920 - val_loss: 0.2630 - val_accuracy: 0.9283
# Epoch 43/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0431 - accuracy: 0.9886 - val_loss: 0.4396 - val_accuracy: 0.8804
# Epoch 44/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0437 - accuracy: 0.9878 - val_loss: 0.2666 - val_accuracy: 0.9380
# Epoch 45/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0337 - accuracy: 0.9910 - val_loss: 0.3296 - val_accuracy: 0.9158
# Epoch 46/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0385 - accuracy: 0.9904 - val_loss: 0.4406 - val_accuracy: 0.8799
# Epoch 47/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0536 - accuracy: 0.9852 - val_loss: 0.2589 - val_accuracy: 0.9283
# Epoch 48/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0263 - accuracy: 0.9913 - val_loss: 0.3355 - val_accuracy: 0.9239
# Epoch 49/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 0.2262 - val_accuracy: 0.9413
# Epoch 50/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0316 - accuracy: 0.9927 - val_loss: 1.0040 - val_accuracy: 0.7842
# Epoch 51/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0322 - accuracy: 0.9912 - val_loss: 0.2648 - val_accuracy: 0.9495
# Epoch 52/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0502 - accuracy: 0.9864 - val_loss: 0.2971 - val_accuracy: 0.9245
# Epoch 53/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0254 - accuracy: 0.9933 - val_loss: 0.1798 - val_accuracy: 0.9511
# Epoch 54/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0331 - accuracy: 0.9912 - val_loss: 0.3897 - val_accuracy: 0.9109
# Epoch 55/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0635 - accuracy: 0.9837 - val_loss: 0.6262 - val_accuracy: 0.8418
# Epoch 56/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0352 - accuracy: 0.9909 - val_loss: 0.2710 - val_accuracy: 0.9283
# Epoch 57/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.1722 - val_accuracy: 0.9554
# Epoch 58/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0329 - accuracy: 0.9902 - val_loss: 0.2086 - val_accuracy: 0.9451
# Epoch 59/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.2261 - val_accuracy: 0.9429
# Epoch 60/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.1957 - val_accuracy: 0.9516
# Epoch 61/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0156 - accuracy: 0.9969 - val_loss: 0.2009 - val_accuracy: 0.9478
# Epoch 62/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.2984 - val_accuracy: 0.9370
# Epoch 63/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0817 - accuracy: 0.9787 - val_loss: 0.2862 - val_accuracy: 0.9255
# Epoch 64/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0459 - accuracy: 0.9867 - val_loss: 0.3125 - val_accuracy: 0.9174
# Epoch 65/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0546 - accuracy: 0.9868 - val_loss: 1.0611 - val_accuracy: 0.7549
# Epoch 66/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0290 - accuracy: 0.9925 - val_loss: 0.2734 - val_accuracy: 0.9375
# Epoch 67/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0332 - accuracy: 0.9920 - val_loss: 0.2992 - val_accuracy: 0.9228
# Epoch 68/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0146 - accuracy: 0.9966 - val_loss: 0.1931 - val_accuracy: 0.9543
# Epoch 69/100
# 230/230 [==============================] - 6s 25ms/step - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.3413 - val_accuracy: 0.9185
# Epoch 70/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0255 - accuracy: 0.9939 - val_loss: 0.2623 - val_accuracy: 0.9326
# Epoch 71/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0353 - accuracy: 0.9902 - val_loss: 0.2388 - val_accuracy: 0.9462
# Epoch 72/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0234 - accuracy: 0.9932 - val_loss: 0.2199 - val_accuracy: 0.9462
# Epoch 73/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.1809 - val_accuracy: 0.9587
# Epoch 74/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1692 - val_accuracy: 0.9625
# Epoch 75/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.1772 - val_accuracy: 0.9636
# Epoch 76/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.2443 - val_accuracy: 0.9489
# Epoch 77/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 0.2581 - val_accuracy: 0.9332
# Epoch 78/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0561 - accuracy: 0.9849 - val_loss: 0.2395 - val_accuracy: 0.9304
# Epoch 79/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0552 - accuracy: 0.9848 - val_loss: 0.3959 - val_accuracy: 0.9087
# Epoch 80/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.1647 - val_accuracy: 0.9625
# Epoch 81/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0097 - accuracy: 0.9976 - val_loss: 0.2083 - val_accuracy: 0.9473
# Epoch 82/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.1433 - val_accuracy: 0.9658
# Epoch 83/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0433 - accuracy: 0.9902 - val_loss: 0.4029 - val_accuracy: 0.8946
# Epoch 84/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0291 - accuracy: 0.9909 - val_loss: 0.1887 - val_accuracy: 0.9505
# Epoch 85/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.2884 - val_accuracy: 0.9375
# Epoch 86/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0284 - accuracy: 0.9929 - val_loss: 0.1726 - val_accuracy: 0.9549
# Epoch 87/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0230 - accuracy: 0.9946 - val_loss: 0.2353 - val_accuracy: 0.9386
# Epoch 88/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.1780 - val_accuracy: 0.9587
# Epoch 89/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.2210 - val_accuracy: 0.9522
# Epoch 90/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.2395 - val_accuracy: 0.9473
# Epoch 91/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0214 - accuracy: 0.9952 - val_loss: 0.2187 - val_accuracy: 0.9489
# Epoch 92/100
# 230/230 [==============================] - 5s 21ms/step - loss: 0.0211 - accuracy: 0.9939 - val_loss: 0.2921 - val_accuracy: 0.9332
# Epoch 93/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0218 - accuracy: 0.9948 - val_loss: 0.2133 - val_accuracy: 0.9467
# Epoch 94/100
# 230/230 [==============================] - 5s 23ms/step - loss: 0.0193 - accuracy: 0.9957 - val_loss: 0.1896 - val_accuracy: 0.9505
# Epoch 95/100
# 230/230 [==============================] - 5s 22ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.1541 - val_accuracy: 0.9647
# Epoch 96/100
# 230/230 [==============================] - 5s 24ms/step - loss: 3.8446e-04 - accuracy: 1.0000 - val_loss: 0.1704 - val_accuracy: 0.9658
# Epoch 97/100
# 230/230 [==============================] - 5s 21ms/step - loss: 6.7878e-04 - accuracy: 0.9997 - val_loss: 0.1775 - val_accuracy: 0.9658
# Epoch 98/100
# 230/230 [==============================] - 5s 22ms/step - loss: 8.0303e-04 - accuracy: 0.9997 - val_loss: 0.1838 - val_accuracy: 0.9647
# Epoch 99/100
# 230/230 [==============================] - 6s 25ms/step - loss: 6.3762e-04 - accuracy: 0.9997 - val_loss: 0.1797 - val_accuracy: 0.9668
# Epoch 100/100
# 230/230 [==============================] - 5s 23ms/step - loss: 3.9094e-04 - accuracy: 0.9997 - val_loss: 0.1825 - val_accuracy: 0.9663

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 58/58 [==============================] - 1s 9ms/step - loss: 0.1825 - accuracy: 0.9663
# Test loss: 0.18248076736927032
# Test accuracy: 0.966304361820221

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = history_model.history['accuracy']
val_acc = history_model.history['val_accuracy']
loss = history_model.history['loss']
val_loss = history_model.history['val_loss']
epochs = range(1, len(loss) + 1)

#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.figure()
#loss plot
plt.plot(epochs, loss, color='pink', label='Training Loss')
plt.plot(epochs, val_loss, color='red', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
"""# Check which layers are trainable in our base model
for layer_number, layer in enumerate(base_model.layers[2].layers):
  print(layer_number, layer.name, layer.trainable)"""
# Out:
# '# Check which layers are trainable in our base model\nfor layer_number, layer in enumerate(base_model.layers[2].layers):\n  print(layer_number, layer.name, layer.trainable)'

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
#from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
preds_probs = model.predict(X_test, verbose=1)
# Out:
# 58/58 [==============================] - 1s 6ms/step

# %%
preds_probs[:10]
# Out:
# array([[1.4485533e-19, 1.4474706e-19, 2.1468255e-19, 2.0809108e-18,
#         1.0000000e+00, 6.7452010e-25, 1.7619700e-16],
#        [2.6719036e-07, 3.5775834e-08, 9.9999905e-01, 2.5191051e-07,
#         5.7635592e-08, 2.8283949e-07, 6.3996529e-12],
#        [2.3175233e-09, 1.0000000e+00, 7.2632844e-11, 4.0916784e-14,
#         6.8170875e-10, 5.7540356e-10, 7.7349805e-16],
#        [1.5968765e-13, 1.6985044e-10, 3.4588018e-06, 9.9998331e-01,
#         2.5182416e-07, 1.2198878e-05, 7.6724467e-07],
#        [6.2181590e-18, 6.2645579e-12, 1.1157563e-07, 9.9999893e-01,
#         4.7065747e-08, 9.1158222e-07, 7.5031947e-10],
#        [1.1816416e-06, 4.6918508e-06, 9.9991643e-01, 2.9905341e-05,
#         4.4507695e-05, 3.3411411e-06, 1.5759412e-09],
#        [9.9999487e-01, 9.6742542e-07, 1.3939498e-06, 1.3043165e-11,
#         5.4811971e-07, 9.9768192e-07, 1.2132498e-06],
#        [1.4941916e-21, 2.0837273e-21, 1.3995683e-20, 8.5480581e-19,
#         1.0000000e+00, 1.5991574e-26, 2.9946615e-17],
#        [9.9999917e-01, 1.7554706e-07, 3.1651417e-08, 3.5327129e-13,
#         8.4340801e-09, 3.9448392e-07, 3.5109593e-07],
#        [8.5134570e-06, 9.9992943e-01, 9.0182903e-06, 2.2506391e-08,
#         5.1523322e-05, 1.5460748e-06, 8.4873530e-10]], dtype=float32)

# %%
# We get one prediction probability per class (in our case there's 101 prediction probabilities)
print(f"Number of prediction probabilities for sample 0: {len(preds_probs[0])}")
print(f"What prediction probability sample 0 looks like:\n {preds_probs[0]}")
print(f"The class with the highest predicted probability by the model for sample 0: {preds_probs[0].argmax()}")
# Out:
# Number of prediction probabilities for sample 0: 7
# What prediction probability sample 0 looks like:
#  [1.4485533e-19 1.4474706e-19 2.1468255e-19 2.0809108e-18 1.0000000e+00
#  6.7452010e-25 1.7619700e-16]
# The class with the highest predicted probability by the model for sample 0: 4

# %%
len(preds_probs)
# Out:
# 1840

# %%
preds_probs.shape
# Out:
# (1840, 7)

# %%
# What does the first prediction probability array look like?
preds_probs[0], len(preds_probs[0]), sum(preds_probs[0])
# Out:
# (array([1.4485533e-19, 1.4474706e-19, 2.1468255e-19, 2.0809108e-18,
#         1.0000000e+00, 6.7452010e-25, 1.7619700e-16], dtype=float32),
#  7,
#  1.0000000000000002)

# %%
# Get the pred classes of each label
pred_classes = preds_probs.argmax(axis=1)

# %%
# How to they look?
pred_classes[:7]
# Out:
# array([4, 2, 1, 3, 3, 2, 0])

# %%
# How many pred classes do we have?
len(pred_classes)
# Out:
# 1840

# %%
#import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
y_test.shape, preds_probs.shape
# Out:
# ((1840,), (1840, 7))

# %%
#y_test = np.argmax(y_test, axis=1)

# %%
preds_probs.shape , y_test.shape
# Out:
# ((1840, 7), (1840,))

# %%
y_test.shape
# Out:
# (1840,)

# %%
preds_probs.shape
# Out:
# (1840, 7)

# %%
preds_probs = np.argmax(preds_probs, axis=1)
preds_probs.shape
# Out:
# (1840,)

# %%
print(metrics.accuracy_score(y_test, preds_probs))
# Out:
# 0.966304347826087

# %%
print(classification_report(y_test, preds_probs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       328
#            1       0.97      0.98      0.98       284
#            2       0.93      0.97      0.95       298
#            3       0.98      0.98      0.98       291
#            4       0.98      0.97      0.97       335
#            5       0.97      0.93      0.95       202
#            6       0.95      0.98      0.97       102
#
#     accuracy                           0.97      1840
#    macro avg       0.97      0.97      0.97      1840
# weighted avg       0.97      0.97      0.97      1840

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('int') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots(figsize=(7, 7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.grid(False)  # Remove the grid lines
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Plotting the confusion matrix
confusion_mtx = confusion_matrix(y_test, preds_probs)
class_names=['surprise', 'disgust', 'fear', 'happy', 'sad', 'neutral', 'angry']
# Plotting non-normalized confusion matrix
plot_confusion_matrix(y_test, preds_probs, classes = class_names, title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# <Axes: title={'center': 'Confusion matrix, without normalization'}, xlabel='Predicted label', ylabel='True label'>

# %%
#Plotting normalized confusion matrix
plot_confusion_matrix(y_test, preds_probs, classes = class_names, normalize = True, title = 'Normalized confusion matrix')
# Out:
# Normalized confusion matrix
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>
