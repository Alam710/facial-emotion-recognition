# %% [markdown]
# <a href="https://colab.research.google.com/github/Alam710/facial-emotion-recognition/blob/master/IMED_ExperimentDWCS48_100_epochs_addandvarian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data Preparation for Classification (Original Image)
import os
from pathlib import Path

data_path = Path('/content/drive/MyDrive/IMED/cropped_data')
label_names = sorted([subfolder.name for subfolder in data_path.glob('*')])
num_classes = len(label_names)

class_counts = [0] * num_classes  # Initialize class counts

# Iterate over each label folder
for i, label_name in enumerate(label_names):
    label_path = data_path / label_name

    # Recursive function to count images in subfolders
    def count_images(folder):
        num_images = 0
        for item in folder.iterdir():
            if item.is_file() and item.suffix.lower() == '.jpg':
                num_images += 1
            elif item.is_dir():
                num_images += count_images(item)
        return num_images

    # Count the number of images within the label folder
    class_counts[i] = count_images(label_path)

# Print the number of images and classes
print('Number of classes:', num_classes)

# Print the number of images for each class
for i, label_name in enumerate(label_names):
    print(f'Class: {label_name}, Number of images: {class_counts[i]}')
# Out:
# Number of classes: 7
# Class: 13_angry, Number of images: 1591
# Class: 14_disgust, Number of images: 1413
# Class: 15_fear, Number of images: 1550
# Class: 16_happy, Number of images: 1322
# Class: 17_sad, Number of images: 1793
# Class: 18_surprise, Number of images: 1051
# Class: 19_neutral, Number of images: 960

# %%
import os
import cv2
import numpy as np
from pathlib import Path
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess_input

data_path = Path('/content/drive/MyDrive/IMED/cropped_data')
label_names = sorted([subfolder.name for subfolder in data_path.glob('*')])
num_classes = len(label_names)
target_image_size = (48, 48)

# Create empty lists for images and labels
images = []
labels = []

# Recursive function to load images from subfolders
def load_images_from_folder(folder):
    for item in folder.iterdir():
        if item.is_dir():
            load_images_from_folder(item)
        elif item.is_file() and item.suffix.lower() == '.jpg':
            # Load the image in color
            image = cv2.imread(str(item))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Resize the image to the target size (224x224)
            image = cv2.resize(image, target_image_size)

            # Preprocess the image
            image = efficientnet_preprocess_input(image)

            # Append the image and label to the lists
            images.append(image)
            labels.append(label_names.index(folder.name))

# Iterate over each label folder
for label_name in label_names:
    label_path = data_path / label_name
    load_images_from_folder(label_path)

# Convert the lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Create an ImageDataGenerator with augmentation settings
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Fit the ImageDataGenerator on your training data
datagen.fit(X_train)

# Define the number of augmented images you want per original image
augmented_images_per_sample = 3

# Create empty lists to store augmented images and labels
augmented_images = []
augmented_labels = []

# Loop through each original image and generate augmented images
for i in range(len(X_train)):
    original_image = X_train[i]
    label = y_train[i]

    # Expand the dimensions of the image to match the expected shape for the generator
    expanded_image = np.expand_dims(original_image, axis=0)

    # Generate augmented images using the generator
    augmented_images_batch = datagen.flow(expanded_image, batch_size=augmented_images_per_sample).next()

    # Append augmented images and labels to the lists
    augmented_images.extend(augmented_images_batch)
    augmented_labels.extend([label] * augmented_images_per_sample)

# Convert lists to numpy arrays
augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

# Concatenate original and augmented data
X_train_augmented = np.concatenate((X_train, augmented_images), axis=0)
y_train_augmented = np.concatenate((y_train, augmented_labels), axis=0)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, BatchNormalization, Activation, MaxPooling2D, Add, SeparableConv2D, Dropout

def conv_block(inputs, filters, kernel_size, strides, padding='same'):
    x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu6')(x)
    return x

def residual_module(inputs, filters, num_blocks, strides):
    x = conv_block(inputs, filters, kernel_size=(1, 1), strides=strides)

    for _ in range(num_blocks):
        y = conv_block(x, filters, kernel_size=(3, 3), strides=(1, 1))
        y = conv_block(y, filters, kernel_size=(3, 3), strides=(1, 1))
        x = Add()([x, y])

    return x

def inverted_residual_structure(inputs, filters, num_blocks):
    x = conv_block(inputs, filters, kernel_size=(1, 1), strides=(1, 1))

    for _ in range(num_blocks):
        y = conv_block(x, filters, kernel_size=(3, 3), strides=(1, 1))
        y = conv_block(y, filters, kernel_size=(3, 3), strides=(1, 1))
        x = Add()([x, y])

    return x

input_shape = (target_image_size[0], target_image_size[1], 3)
num_classes = 7

inputs = tf.keras.Input(shape=input_shape)
x = conv_block(inputs, filters=32, kernel_size=(5, 5), strides=(1, 1))
x = MaxPooling2D(2, 2)(x)
x = conv_block(x, filters=64, kernel_size=(5, 5), strides=(1, 1))
x = MaxPooling2D(2, 2)(x)
x = residual_module(x, filters=128, num_blocks=2, strides=(2, 2))
x = inverted_residual_structure(x, filters=256, num_blocks=4)
x = residual_module(x, filters=256, num_blocks=2, strides=(2, 2))
x = residual_module(x, filters=364, num_blocks=1, strides=(1, 1))
x = residual_module(x, filters=364, num_blocks=2, strides=(2, 2))
x = inverted_residual_structure(x, filters=512, num_blocks=1)
x = SeparableConv2D(filters=728, kernel_size=(1, 1), strides=(1, 1), padding='same')(x)
x = GlobalAveragePooling2D()(x)

outputs = Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d_32 (Conv2D)             (None, 48, 48, 32)   2432        ['input_2[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 48, 48, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 48, 48, 32)   0           ['batch_normalization_32[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 32)  0           ['activation_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 24, 24, 64)   51264       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 24, 24, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 24, 24, 64)   0           ['batch_normalization_33[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_34[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 6, 6, 128)    8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 6, 6, 128)   512         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 6, 6, 128)    147584      ['activation_35[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 6, 6, 128)   512         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 6, 6, 128)    147584      ['activation_36[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 6, 6, 128)   512         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_36[0][0]']
#
#  add_12 (Add)                   (None, 6, 6, 128)    0           ['activation_35[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 6, 6, 128)    147584      ['add_12[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 6, 6, 128)   512         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 6, 6, 128)    147584      ['activation_38[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 6, 6, 128)   512         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_38[0][0]']
#
#  add_13 (Add)                   (None, 6, 6, 128)    0           ['add_12[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 6, 6, 256)    33024       ['add_13[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_40[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_41[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_41[0][0]']
#
#  add_14 (Add)                   (None, 6, 6, 256)    0           ['activation_40[0][0]',
#                                                                   'activation_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 6, 6, 256)    590080      ['add_14[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_43[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_43[0][0]']
#
#  add_15 (Add)                   (None, 6, 6, 256)    0           ['add_14[0][0]',
#                                                                   'activation_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 6, 6, 256)    590080      ['add_15[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_45[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_45[0][0]']
#
#  add_16 (Add)                   (None, 6, 6, 256)    0           ['add_15[0][0]',
#                                                                   'activation_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 6, 6, 256)    590080      ['add_16[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_47[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_47[0][0]']
#
#  add_17 (Add)                   (None, 6, 6, 256)    0           ['add_16[0][0]',
#                                                                   'activation_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 3, 3, 256)    65792       ['add_17[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_49[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_50[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_50[0][0]']
#
#  add_18 (Add)                   (None, 3, 3, 256)    0           ['activation_49[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 3, 3, 256)    590080      ['add_18[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 3, 3, 256)    590080      ['activation_52[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 3, 3, 256)   1024        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 3, 3, 256)    0           ['batch_normalization_52[0][0]']
#
#  add_19 (Add)                   (None, 3, 3, 256)    0           ['add_18[0][0]',
#                                                                   'activation_53[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 3, 3, 364)    93548       ['add_19[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 3, 3, 364)    1192828     ['activation_54[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 3, 3, 364)    1192828     ['activation_55[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 3, 3, 364)   1456        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 3, 3, 364)    0           ['batch_normalization_55[0][0]']
#
#  add_20 (Add)                   (None, 3, 3, 364)    0           ['activation_54[0][0]',
#                                                                   'activation_56[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 364)    132860      ['add_20[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_57[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_58[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_58[0][0]']
#
#  add_21 (Add)                   (None, 2, 2, 364)    0           ['activation_57[0][0]',
#                                                                   'activation_59[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 2, 2, 364)    1192828     ['add_21[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 2, 2, 364)    1192828     ['activation_60[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 2, 2, 364)   1456        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 2, 2, 364)    0           ['batch_normalization_60[0][0]']
#
#  add_22 (Add)                   (None, 2, 2, 364)    0           ['add_21[0][0]',
#                                                                   'activation_61[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 2, 2, 512)    186880      ['add_22[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_62[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_63[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_63[0][0]']
#
#  add_23 (Add)                   (None, 2, 2, 512)    0           ['activation_62[0][0]',
#                                                                   'activation_64[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 2, 2, 728)   373976      ['add_23[0][0]']
#  onv2D)
#
#  global_average_pooling2d_1 (Gl  (None, 728)         0           ['separable_conv2d_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 7)            5103        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 20,536,151
# Trainable params: 20,518,615
# Non-trainable params: 17,536
# __________________________________________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') >= 0.98):
      print("\nAkurasi telah mencapai > 0.98%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# Train the model with early stopping
history_model = model.fit(X_train, y_train, epochs=100,
                          batch_size=32,
                          validation_data=(X_test, y_test),
                          callbacks=[callbacks])
# Out:
# Epoch 1/100
# 242/242 [==============================] - 29s 30ms/step - loss: 1.6483 - accuracy: 0.3090 - val_loss: 7.7411 - val_accuracy: 0.2118
# Epoch 2/100
# 242/242 [==============================] - 6s 27ms/step - loss: 1.1564 - accuracy: 0.4963 - val_loss: 2.3084 - val_accuracy: 0.4013
# Epoch 3/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.8698 - accuracy: 0.6418 - val_loss: 2.1209 - val_accuracy: 0.5434
# Epoch 4/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.6248 - accuracy: 0.7783 - val_loss: 0.7704 - val_accuracy: 0.7743
# Epoch 5/100
# 242/242 [==============================] - 7s 27ms/step - loss: 0.4792 - accuracy: 0.8341 - val_loss: 1.4829 - val_accuracy: 0.7144
# Epoch 6/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.3800 - accuracy: 0.8735 - val_loss: 0.4235 - val_accuracy: 0.8709
# Epoch 7/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.3248 - accuracy: 0.8887 - val_loss: 0.5555 - val_accuracy: 0.8311
# Epoch 8/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.2819 - accuracy: 0.9044 - val_loss: 0.5907 - val_accuracy: 0.8285
# Epoch 9/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.2520 - accuracy: 0.9199 - val_loss: 0.5344 - val_accuracy: 0.8332
# Epoch 10/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.2134 - accuracy: 0.9270 - val_loss: 0.4944 - val_accuracy: 0.8564
# Epoch 11/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1953 - accuracy: 0.9375 - val_loss: 0.3145 - val_accuracy: 0.9024
# Epoch 12/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.1805 - accuracy: 0.9393 - val_loss: 0.7818 - val_accuracy: 0.7701
# Epoch 13/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1721 - accuracy: 0.9403 - val_loss: 0.3706 - val_accuracy: 0.8760
# Epoch 14/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1416 - accuracy: 0.9545 - val_loss: 0.4650 - val_accuracy: 0.8642
# Epoch 15/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.1492 - accuracy: 0.9531 - val_loss: 0.4573 - val_accuracy: 0.8569
# Epoch 16/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1086 - accuracy: 0.9657 - val_loss: 0.3043 - val_accuracy: 0.9143
# Epoch 17/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1182 - accuracy: 0.9618 - val_loss: 0.3505 - val_accuracy: 0.8977
# Epoch 18/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0986 - accuracy: 0.9688 - val_loss: 0.2157 - val_accuracy: 0.9396
# Epoch 19/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0879 - accuracy: 0.9720 - val_loss: 0.2926 - val_accuracy: 0.9132
# Epoch 20/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1060 - accuracy: 0.9672 - val_loss: 0.3754 - val_accuracy: 0.8957
# Epoch 21/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0934 - accuracy: 0.9699 - val_loss: 0.3280 - val_accuracy: 0.9003
# Epoch 22/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0909 - accuracy: 0.9738 - val_loss: 0.2454 - val_accuracy: 0.9282
# Epoch 23/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0790 - accuracy: 0.9751 - val_loss: 0.2302 - val_accuracy: 0.9329
# Epoch 24/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0803 - accuracy: 0.9748 - val_loss: 0.3360 - val_accuracy: 0.8982
# Epoch 25/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.1004 - accuracy: 0.9698 - val_loss: 0.2629 - val_accuracy: 0.9241
# Epoch 26/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0861 - accuracy: 0.9726 - val_loss: 1.0019 - val_accuracy: 0.7949
# Epoch 27/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0718 - accuracy: 0.9786 - val_loss: 0.2471 - val_accuracy: 0.9298
# Epoch 28/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0757 - accuracy: 0.9780 - val_loss: 0.2354 - val_accuracy: 0.9282
# Epoch 29/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0479 - accuracy: 0.9864 - val_loss: 0.3188 - val_accuracy: 0.9081
# Epoch 30/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0556 - accuracy: 0.9826 - val_loss: 0.2156 - val_accuracy: 0.9339
# Epoch 31/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0589 - accuracy: 0.9835 - val_loss: 0.3664 - val_accuracy: 0.9003
# Epoch 32/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0587 - accuracy: 0.9831 - val_loss: 0.2580 - val_accuracy: 0.9251
# Epoch 33/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0629 - accuracy: 0.9833 - val_loss: 0.2262 - val_accuracy: 0.9416
# Epoch 34/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0513 - accuracy: 0.9859 - val_loss: 0.2055 - val_accuracy: 0.9360
# Epoch 35/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0747 - accuracy: 0.9786 - val_loss: 0.3142 - val_accuracy: 0.9179
# Epoch 36/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 0.3100 - val_accuracy: 0.9261
# Epoch 37/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0531 - accuracy: 0.9848 - val_loss: 0.2195 - val_accuracy: 0.9401
# Epoch 38/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.2780 - val_accuracy: 0.9220
# Epoch 39/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0359 - accuracy: 0.9901 - val_loss: 0.2183 - val_accuracy: 0.9390
# Epoch 40/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0389 - accuracy: 0.9907 - val_loss: 0.3250 - val_accuracy: 0.9112
# Epoch 41/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0517 - accuracy: 0.9861 - val_loss: 0.2765 - val_accuracy: 0.9313
# Epoch 42/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0353 - accuracy: 0.9904 - val_loss: 0.2838 - val_accuracy: 0.9251
# Epoch 43/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0538 - accuracy: 0.9851 - val_loss: 0.2346 - val_accuracy: 0.9360
# Epoch 44/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0379 - accuracy: 0.9888 - val_loss: 0.2480 - val_accuracy: 0.9380
# Epoch 45/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0238 - accuracy: 0.9939 - val_loss: 0.2142 - val_accuracy: 0.9416
# Epoch 46/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0526 - accuracy: 0.9862 - val_loss: 0.2832 - val_accuracy: 0.9158
# Epoch 47/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0325 - accuracy: 0.9917 - val_loss: 0.1673 - val_accuracy: 0.9551
# Epoch 48/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0409 - accuracy: 0.9904 - val_loss: 0.2382 - val_accuracy: 0.9349
# Epoch 49/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0465 - accuracy: 0.9858 - val_loss: 0.2468 - val_accuracy: 0.9298
# Epoch 50/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0546 - accuracy: 0.9862 - val_loss: 0.3050 - val_accuracy: 0.9334
# Epoch 51/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0468 - accuracy: 0.9880 - val_loss: 0.4020 - val_accuracy: 0.8998
# Epoch 52/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.2548 - val_accuracy: 0.9339
# Epoch 53/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0418 - accuracy: 0.9899 - val_loss: 0.1549 - val_accuracy: 0.9576
# Epoch 54/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.2219 - val_accuracy: 0.9390
# Epoch 55/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0292 - accuracy: 0.9917 - val_loss: 0.1999 - val_accuracy: 0.9416
# Epoch 56/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0252 - accuracy: 0.9933 - val_loss: 0.2152 - val_accuracy: 0.9489
# Epoch 57/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.3901 - val_accuracy: 0.8972
# Epoch 58/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0414 - accuracy: 0.9894 - val_loss: 0.2196 - val_accuracy: 0.9427
# Epoch 59/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 0.2526 - val_accuracy: 0.9344
# Epoch 60/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0329 - accuracy: 0.9919 - val_loss: 0.2688 - val_accuracy: 0.9458
# Epoch 61/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0423 - accuracy: 0.9898 - val_loss: 0.1973 - val_accuracy: 0.9478
# Epoch 62/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0297 - accuracy: 0.9925 - val_loss: 0.2350 - val_accuracy: 0.9390
# Epoch 63/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0460 - accuracy: 0.9876 - val_loss: 0.1757 - val_accuracy: 0.9509
# Epoch 64/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0181 - accuracy: 0.9955 - val_loss: 0.1780 - val_accuracy: 0.9514
# Epoch 65/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0312 - accuracy: 0.9908 - val_loss: 0.2095 - val_accuracy: 0.9432
# Epoch 66/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0255 - accuracy: 0.9932 - val_loss: 0.1889 - val_accuracy: 0.9520
# Epoch 67/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0247 - accuracy: 0.9943 - val_loss: 0.4316 - val_accuracy: 0.8993
# Epoch 68/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0244 - accuracy: 0.9930 - val_loss: 0.1684 - val_accuracy: 0.9576
# Epoch 69/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0359 - accuracy: 0.9897 - val_loss: 0.2268 - val_accuracy: 0.9452
# Epoch 70/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0266 - accuracy: 0.9934 - val_loss: 0.2242 - val_accuracy: 0.9380
# Epoch 71/100
# 242/242 [==============================] - 7s 27ms/step - loss: 0.0346 - accuracy: 0.9920 - val_loss: 0.2226 - val_accuracy: 0.9458
# Epoch 72/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.1681 - val_accuracy: 0.9607
# Epoch 73/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.2587 - val_accuracy: 0.9277
# Epoch 74/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.1441 - val_accuracy: 0.9680
# Epoch 75/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.1835 - val_accuracy: 0.9561
# Epoch 76/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.1603 - val_accuracy: 0.9597
# Epoch 77/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0270 - accuracy: 0.9928 - val_loss: 0.2905 - val_accuracy: 0.9236
# Epoch 78/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0367 - accuracy: 0.9901 - val_loss: 0.2701 - val_accuracy: 0.9267
# Epoch 79/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0453 - accuracy: 0.9882 - val_loss: 0.3052 - val_accuracy: 0.9137
# Epoch 80/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.4938 - val_accuracy: 0.8858
# Epoch 81/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0479 - accuracy: 0.9885 - val_loss: 0.1797 - val_accuracy: 0.9509
# Epoch 82/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.1554 - val_accuracy: 0.9664
# Epoch 83/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0216 - accuracy: 0.9952 - val_loss: 0.2899 - val_accuracy: 0.9411
# Epoch 84/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.1417 - val_accuracy: 0.9680
# Epoch 85/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0252 - accuracy: 0.9924 - val_loss: 0.2496 - val_accuracy: 0.9370
# Epoch 86/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0230 - accuracy: 0.9935 - val_loss: 0.4880 - val_accuracy: 0.8755
# Epoch 87/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0168 - accuracy: 0.9960 - val_loss: 0.1986 - val_accuracy: 0.9473
# Epoch 88/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0160 - accuracy: 0.9969 - val_loss: 0.1715 - val_accuracy: 0.9638
# Epoch 89/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0108 - accuracy: 0.9973 - val_loss: 0.1577 - val_accuracy: 0.9602
# Epoch 90/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0218 - accuracy: 0.9946 - val_loss: 1.0321 - val_accuracy: 0.7769
# Epoch 91/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0333 - accuracy: 0.9923 - val_loss: 0.2136 - val_accuracy: 0.9545
# Epoch 92/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.1492 - val_accuracy: 0.9659
# Epoch 93/100
# 242/242 [==============================] - 6s 26ms/step - loss: 8.2058e-04 - accuracy: 0.9999 - val_loss: 0.1455 - val_accuracy: 0.9716
# Epoch 94/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0403 - accuracy: 0.9899 - val_loss: 0.3699 - val_accuracy: 0.8926
# Epoch 95/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.2953 - val_accuracy: 0.9189
# Epoch 96/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.2296 - val_accuracy: 0.9370
# Epoch 97/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.1730 - val_accuracy: 0.9592
# Epoch 98/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0207 - accuracy: 0.9952 - val_loss: 0.1584 - val_accuracy: 0.9566
# Epoch 99/100
# 242/242 [==============================] - 6s 26ms/step - loss: 0.0258 - accuracy: 0.9934 - val_loss: 0.1841 - val_accuracy: 0.9535
# Epoch 100/100
# 242/242 [==============================] - 6s 27ms/step - loss: 0.0149 - accuracy: 0.9961 - val_loss: 0.2317 - val_accuracy: 0.9437

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2317 - accuracy: 0.9437
# Test loss: 0.2316931039094925
# Test accuracy: 0.9436983466148376

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = history_model.history['accuracy']
val_acc = history_model.history['val_accuracy']
loss = history_model.history['loss']
val_loss = history_model.history['val_loss']
epochs = range(1, len(loss) + 1)

#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.figure()
#loss plot
plt.plot(epochs, loss, color='pink', label='Training Loss')
plt.plot(epochs, val_loss, color='red', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
# from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
preds_probs = model.predict(X_test, verbose=1)
# Out:
# 61/61 [==============================] - 1s 5ms/step

# %%
preds_probs[:10]
# Out:
# array([[8.13e-06, 3.09e-05, 1.00e+00, 1.34e-07, 2.24e-04, 1.87e-05,
#         3.00e-10],
#        [1.00e+00, 7.37e-18, 4.05e-13, 1.39e-29, 4.11e-27, 3.16e-20,
#         3.02e-24],
#        [1.79e-15, 7.03e-15, 2.57e-12, 1.26e-14, 1.00e+00, 2.10e-10,
#         1.28e-10],
#        [1.27e-09, 4.69e-15, 1.10e-08, 1.25e-07, 8.08e-08, 1.00e+00,
#         1.07e-08],
#        [1.00e+00, 8.13e-13, 1.58e-09, 1.31e-22, 1.93e-20, 3.13e-16,
#         1.29e-18],
#        [9.80e-20, 1.97e-15, 6.79e-16, 1.00e+00, 2.46e-12, 9.09e-09,
#         1.02e-09],
#        [2.04e-05, 5.10e-05, 1.00e+00, 1.10e-07, 8.01e-05, 9.95e-06,
#         3.70e-10],
#        [3.45e-06, 5.40e-05, 9.99e-01, 1.21e-07, 1.04e-03, 4.18e-06,
#         5.31e-10],
#        [3.26e-06, 1.71e-09, 2.32e-11, 1.32e-06, 5.59e-07, 5.66e-07,
#         1.00e+00],
#        [1.00e+00, 6.85e-15, 3.09e-11, 1.57e-26, 2.20e-23, 4.61e-19,
#         8.47e-21]], dtype=float32)

# %%
# We get one prediction probability per class (in our case there's 101 prediction probabilities)
print(f"Number of prediction probabilities for sample 0: {len(preds_probs[0])}")
print(f"What prediction probability sample 0 looks like:\n {preds_probs[0]}")
print(f"The class with the highest predicted probability by the model for sample 0: {preds_probs[0].argmax()}")
# Out:
# Number of prediction probabilities for sample 0: 7
# What prediction probability sample 0 looks like:
#  [8.13e-06 3.09e-05 1.00e+00 1.34e-07 2.24e-04 1.87e-05 3.00e-10]
# The class with the highest predicted probability by the model for sample 0: 2

# %%
len(preds_probs)
# Out:
# 1936

# %%
preds_probs.shape
# Out:
# (1936, 7)

# %%
# What does the first prediction probability array look like?
preds_probs[0], len(preds_probs[0]), sum(preds_probs[0])
# Out:
# (array([8.13e-06, 3.09e-05, 1.00e+00, 1.34e-07, 2.24e-04, 1.87e-05,
#         3.00e-10], dtype=float32),
#  7,
#  0.999999948216538)

# %%
# Get the pred classes of each label
pred_classes = preds_probs.argmax(axis=1)

# %%
# How to they look?
pred_classes[:7]
# Out:
# array([2, 0, 4, 5, 0, 3, 2])

# %%
# How many pred classes do we have?
len(pred_classes)
# Out:
# 1936

# %%
#import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
y_test.shape, preds_probs.shape
# Out:
# ((1936,), (1936, 7))

# %%
#y_test = np.argmax(y_test, axis=1)

# %%
preds_probs.shape , y_test.shape
# Out:
# ((1936, 7), (1936,))

# %%
y_test.shape
# Out:
# (1936,)

# %%
preds_probs.shape
# Out:
# (1936, 7)

# %%
preds_probs = np.argmax(preds_probs, axis=1)
preds_probs.shape
# Out:
# (1936,)

# %%
print(metrics.accuracy_score(y_test, preds_probs))
# Out:
# 0.943698347107438

# %%
print(classification_report(y_test, preds_probs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       329
#            1       0.98      0.93      0.96       277
#            2       0.94      0.94      0.94       325
#            3       0.98      0.93      0.96       259
#            4       0.96      0.96      0.96       358
#            5       0.89      0.91      0.90       204
#            6       0.89      0.99      0.94       184
#
#     accuracy                           0.94      1936
#    macro avg       0.94      0.94      0.94      1936
# weighted avg       0.94      0.94      0.94      1936

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('int') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots(figsize=(7, 7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.grid(False)  # Remove the grid lines
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Plotting the confusion matrix
confusion_mtx = confusion_matrix(y_test, preds_probs)
class_names=['surprise', 'disgust', 'fear', 'happy', 'sad', 'neutral', 'angry']
# Plotting non-normalized confusion matrix
plot_confusion_matrix(y_test, preds_probs, classes = class_names, title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# <Axes: title={'center': 'Confusion matrix, without normalization'}, xlabel='Predicted label', ylabel='True label'>

# %%
#Plotting normalized confusion matrix
plot_confusion_matrix(y_test, preds_probs, classes = class_names, normalize = True, title = 'Normalized confusion matrix')
# Out:
# Normalized confusion matrix
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>
